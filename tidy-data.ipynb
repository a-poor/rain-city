# %%
import json
import datetime as dt
from pathlib import Path

import pandas as pd

# %%
DATA_DIR = Path("./data")
input_data = DATA_DIR / "openweather-history-seattle.json"

# %%
data = json.loads(input_data.read_text())
len(data)
# Out:
# 371376

# %%
def format_rows(rows: [dict]) -> [dict]:
    for row in rows:
        weather = row["weather"] if () else []
        d = {k: v for k, v in row.items() if not isinstance(v,(dict,list))}
        d = {**d,**{f"main_{k}": v for k, v in row.get("main",{}).items()}}
        d = {**d,**{f"wind_{k}": v for k, v in row.get("wind",{}).items()}}
        d = {**d,**{f"clouds_{k}": v for k, v in row.get("clouds",{}).items()}}
        d = {**d,**{f"weather_{k}": v for k, v in row["weather"][0].items()}}
        yield d

# %%
df = pd.DataFrame(list(format_rows(data)))
df.head()
# Out:
#           dt                         dt_iso  timezone        lat city_name  \
# 0  283996800  1979-01-01 00:00:00 +0000 UTC    -28800  47.606209   Seattle
# 1  284000400  1979-01-01 01:00:00 +0000 UTC    -28800  47.606209   Seattle
# 2  284004000  1979-01-01 02:00:00 +0000 UTC    -28800  47.606209   Seattle
# 3  284007600  1979-01-01 03:00:00 +0000 UTC    -28800  47.606209   Seattle
# 4  284011200  1979-01-01 04:00:00 +0000 UTC    -28800  47.606209   Seattle
#
#           lon  main_temp  main_temp_min  main_temp_max  main_feels_like  \
# 0 -122.332071      17.24          12.94          21.06             7.61
# 1 -122.332071      16.90          11.84          21.33             6.76
# 2 -122.332071      16.56          11.62          20.93             6.78
# 3 -122.332071       8.62           3.64          13.08            -1.28
# 4 -122.332071       8.15           2.75          12.93            -1.73
#
#    main_pressure  main_humidity  wind_speed  wind_deg  clouds_all  weather_id  \
# 0           1039             46        5.91        56          99         804
# 1           1039             46        6.78        63         100         804
# 2           1039             46        6.11        66          53         803
# 3           1040             52        6.04        72           0         800
# 4           1040             53        5.99        80           0         800
#
#   weather_main weather_description weather_icon
# 0       Clouds     overcast clouds          04d
# 1       Clouds     overcast clouds          04n
# 2       Clouds       broken clouds          04n
# 3        Clear        sky is clear          01n
# 4        Clear        sky is clear          01n

# %%
df["dt_utc"] = df.dt_iso.apply(lambda d: dt.datetime.strptime(d,"%Y-%m-%d %H:%M:%S %z %Z"))
df["dt_local"] = df.dt_utc + df.timezone.apply(lambda s: dt.timedelta(seconds=s))
df = df.drop(columns=["dt_iso","timezone","dt"])
df.head()
# Out:
#          lat city_name         lon  main_temp  main_temp_min  main_temp_max  \
# 0  47.606209   Seattle -122.332071      17.24          12.94          21.06
# 1  47.606209   Seattle -122.332071      16.90          11.84          21.33
# 2  47.606209   Seattle -122.332071      16.56          11.62          20.93
# 3  47.606209   Seattle -122.332071       8.62           3.64          13.08
# 4  47.606209   Seattle -122.332071       8.15           2.75          12.93
#
#    main_feels_like  main_pressure  main_humidity  wind_speed  wind_deg  \
# 0             7.61           1039             46        5.91        56
# 1             6.76           1039             46        6.78        63
# 2             6.78           1039             46        6.11        66
# 3            -1.28           1040             52        6.04        72
# 4            -1.73           1040             53        5.99        80
#
#    clouds_all  weather_id weather_main weather_description weather_icon  \
# 0          99         804       Clouds     overcast clouds          04d
# 1         100         804       Clouds     overcast clouds          04n
# 2          53         803       Clouds       broken clouds          04n
# 3           0         800        Clear        sky is clear          01n
# 4           0         800        Clear        sky is clear          01n
#
#                      dt_utc                  dt_local
# 0 1979-01-01 00:00:00+00:00 1978-12-31 16:00:00+00:00
# 1 1979-01-01 01:00:00+00:00 1978-12-31 17:00:00+00:00
# 2 1979-01-01 02:00:00+00:00 1978-12-31 18:00:00+00:00
# 3 1979-01-01 03:00:00+00:00 1978-12-31 19:00:00+00:00
# 4 1979-01-01 04:00:00+00:00 1978-12-31 20:00:00+00:00

# %%
df.to_csv(DATA_DIR/"tidy-data.csv", index=False)
